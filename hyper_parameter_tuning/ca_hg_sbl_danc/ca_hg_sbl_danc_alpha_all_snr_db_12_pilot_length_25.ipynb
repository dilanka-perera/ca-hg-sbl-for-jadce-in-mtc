# %%
base_path = "/content/drive/My Drive/Github/ca-hg-sbl-for-jadce-in-mtc"

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# Load saved data
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append(f'{base_path}/frameworks')

from ca_hg_sbl import ca_hg_sbl, build_precision_matrix_anc, build_precision_matrix_danc

data = np.load(f'{base_path}/general_model/data/general_model.npz', allow_pickle=True)
all_DeviceLocations = data['all_DeviceLocations']
num_samples = data['num_samples']
device_count = data['device_count']
sparsity = data['sparsity']

data = np.load(f'{base_path}/communication_model/data/communication_simulation_theta.npz', allow_pickle=True)
all_theta = data["all_theta"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_gamma.npz', allow_pickle=True)
all_gamma = data["all_gamma"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_z.npz', allow_pickle=True)
all_z = data["all_z"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_noise.npz', allow_pickle=True)
all_noise = data["all_noise"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_received_signal.npz', allow_pickle=True)
all_received_signal = data["all_received_signal"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_general.npz', allow_pickle=True)
snr_db_array = data["snr_db_array"]
pilot_length_array = data["pilot_length_array"]
M = data["M"]

pilot_length_index = 1
pilot_length=pilot_length_array[pilot_length_index]

snr_db_index = 2
snr_db=snr_db_array[snr_db_index]

beta_array = [-1, -0.5, 0, 0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
sample_range = range(0, 10)
num_samples = len(sample_range)

# %%
# Final gamma and z results
gamma_result_all = np.empty((num_samples, len(beta_array)), dtype=object)
z_result_all = np.empty((num_samples, len(beta_array)), dtype=object)

# %%
for sample_index in tqdm(sample_range, desc="Processing Samples", position=0):
    gamma = all_gamma[sample_index]  # Ground truth gamma values (true support)
    loc = all_DeviceLocations[sample_index]
    z = all_z[sample_index]

    for beta_index in tqdm(range(len(beta_array)), desc="Processing alpha Levels", leave=False, position=1):
        alpha = 1.0
        beta = beta_array[beta_index]

        theta = all_theta[sample_index, pilot_length_index, :pilot_length]
        received_signal = all_received_signal[sample_index, pilot_length_index, snr_db_index, :pilot_length]

        # Compute noise
        snr = 10 ** (snr_db / 10)
        signal_power = np.mean(np.abs(np.matmul(theta, z))**2)
        noise_power = signal_power / snr

        # Compute precision matrix
        precision_matrix = build_precision_matrix_danc(loc, alpha=alpha, beta=beta)

        # Run CASBL
        gamma_result, z_result, gamma_history, z_history, iteration_count = ca_hg_sbl(
            theta, received_signal, noise_power, precision_matrix, bounded = False
        )

        # Save outputs
        gamma_result_all[sample_index-sample_range[0], beta_index] = gamma_result.copy()
        z_result_all[sample_index-sample_range[0], beta_index] = z_result.copy()
# Out:
# Processing Samples:   0%|          | 0/10 [00:00<?, ?it/s]
# Processing alpha Levels:   0%|          | 0/15 [00:00<?, ?it/s]
# Processing alpha Levels:   7%|▋         | 1/15 [00:14<03:29, 14.98s/it]
# Processing alpha Levels:  13%|█▎        | 2/15 [00:29<03:14, 14.99s/it]
# Processing alpha Levels:  20%|██        | 3/15 [00:44<03:00, 15.00s/it]
# Processing alpha Levels:  27%|██▋       | 4/15 [01:00<02:45, 15.02s/it]
# Processing alpha Levels:  33%|███▎      | 5/15 [01:15<02:30, 15.06s/it]
# Processing alpha Levels:  40%|████      | 6/15 [01:30<02:15, 15.07s/it]
# Processing alpha Levels:  47%|████▋     | 7/15 [01:45<02:00, 15.12s/it]
# Processing alpha Levels:  53%|█████▎    | 8/15 [02:02<01:49, 15.58s/it]
# Processing alpha Levels:  60%|██████    | 9/15 [02:18<01:34, 15.79s/it]
# Processing alpha Levels:  67%|██████▋   | 10/15 [02:33<01:18, 15.73s/it]
# Processing alpha Levels:  73%|███████▎  | 11/15 [02:49<01:02, 15.55s/it]
# Processing alpha Levels:  80%|████████  | 12/15 [03:03<00:46, 15.37s/it]
# Processing alpha Levels:  87%|████████▋ | 13/15 [03:19<00:30, 15.31s/it]
# Processing alpha Levels:  93%|█████████▎| 14/15 [03:34<00:15, 15.23s/it]
# Processing alpha Levels: 100%|██████████| 15/15 [03:49<00:00, 15.21s/it]
# Processing Samples:  10%|█         | 1/10 [03:49<34:24, 229.41s/it]
# Processing alpha Levels:   0%|          | 0/15 [00:00<?, ?it/s]
# Processing alpha Levels:   7%|▋         | 1/15 [00:15<03:32, 15.16s/it]
# Processing alpha Levels:  13%|█▎        | 2/15 [00:30<03:17, 15.17s/it]
# Processing alpha Levels:  20%|██        | 3/15 [00:45<03:01, 15.15s/it]
# Processing alpha Levels:  27%|██▋       | 4/15 [01:00<02:46, 15.16s/it]
# Processing alpha Levels:  33%|███▎      | 5/15 [01:16<02:32, 15.24s/it]
# Processing alpha Levels:  40%|████      | 6/15 [01:31<02:16, 15.21s/it]
# Processing alpha Levels:  47%|████▋     | 7/15 [01:46<02:02, 15.27s/it]
# Processing alpha Levels:  53%|█████▎    | 8/15 [02:01<01:46, 15.22s/it]
# Processing alpha Levels:  60%|██████    | 9/15 [02:16<01:31, 15.25s/it]
# Processing alpha Levels:  67%|██████▋   | 10/15 [02:32<01:16, 15.23s/it]
# Processing alpha Levels:  73%|███████▎  | 11/15 [02:47<01:00, 15.22s/it]
# Processing alpha Levels:  80%|████████  | 12/15 [03:02<00:45, 15.20s/it]
# Processing alpha Levels:  87%|████████▋ | 13/15 [03:17<00:30, 15.23s/it]
# Processing alpha Levels:  93%|█████████▎| 14/15 [03:33<00:15, 15.22s/it]
# Processing alpha Levels: 100%|██████████| 15/15 [03:48<00:00, 15.21s/it]
# Processing Samples:  20%|██        | 2/10 [07:37<30:29, 228.71s/it]
# Processing alpha Levels:   0%|          | 0/15 [00:00<?, ?it/s]
# Processing alpha Levels:   7%|▋         | 1/15 [00:15<03:31, 15.14s/it]
# Processing alpha Levels:  13%|█▎        | 2/15 [00:30<03:17, 15.16s/it]
# Processing alpha Levels:  20%|██        | 3/15 [00:45<03:01, 15.15s/it]
# Processing alpha Levels:  27%|██▋       | 4/15 [01:00<02:46, 15.15s/it]
# Processing alpha Levels:  33%|███▎      | 5/15 [01:15<02:31, 15.11s/it]
# Processing alpha Levels:  40%|████      | 6/15 [01:30<02:16, 15.16s/it]
# Processing alpha Levels:  47%|████▋     | 7/15 [01:47<02:04, 15.60s/it]
# Processing alpha Levels:  53%|█████▎    | 8/15 [02:03<01:49, 15.66s/it]
# Processing alpha Levels:  60%|██████    | 9/15 [02:18<01:32, 15.46s/it]
# Processing alpha Levels:  67%|██████▋   | 10/15 [02:33<01:16, 15.40s/it]
# Processing alpha Levels:  73%|███████▎  | 11/15 [02:48<01:01, 15.38s/it]
# Processing alpha Levels:  80%|████████  | 12/15 [03:03<00:45, 15.25s/it]
# Processing alpha Levels:  87%|████████▋ | 13/15 [03:18<00:30, 15.14s/it]
# Processing alpha Levels:  93%|█████████▎| 14/15 [03:33<00:15, 15.09s/it]
# Processing alpha Levels: 100%|██████████| 15/15 [03:48<00:00, 15.05s/it]
# Processing Samples:  30%|███       | 3/10 [11:26<26:40, 228.66s/it]
# Processing alpha Levels:   0%|          | 0/15 [00:00<?, ?it/s]
# Processing alpha Levels:   7%|▋         | 1/15 [00:14<03:29, 14.99s/it]
# Processing alpha Levels:  13%|█▎        | 2/15 [00:29<03:14, 14.97s/it]
# Processing alpha Levels:  20%|██        | 3/15 [00:45<03:00, 15.02s/it]
# Processing alpha Levels:  27%|██▋       | 4/15 [00:59<02:44, 15.00s/it]
# Processing alpha Levels:  33%|███▎      | 5/15 [01:15<02:30, 15.02s/it]
# Processing alpha Levels:  40%|████      | 6/15 [01:30<02:15, 15.05s/it]
# Processing alpha Levels:  47%|████▋     | 7/15 [01:45<02:00, 15.12s/it]
# Processing alpha Levels:  53%|█████▎    | 8/15 [02:00<01:45, 15.08s/it]
# Processing alpha Levels:  60%|██████    | 9/15 [02:15<01:30, 15.05s/it]
# Processing alpha Levels:  67%|██████▋   | 10/15 [02:30<01:15, 15.08s/it]
# Processing alpha Levels:  73%|███████▎  | 11/15 [02:45<01:00, 15.06s/it]
# Processing alpha Levels:  80%|████████  | 12/15 [03:00<00:45, 15.03s/it]
# Processing alpha Levels:  87%|████████▋ | 13/15 [03:15<00:30, 15.03s/it]
# Processing alpha Levels:  93%|█████████▎| 14/15 [03:30<00:15, 15.04s/it]
# Processing alpha Levels: 100%|██████████| 15/15 [03:45<00:00, 15.07s/it]
# Processing Samples:  40%|████      | 4/10 [15:11<22:45, 227.52s/it]
# Processing alpha Levels:   0%|          | 0/15 [00:00<?, ?it/s]
# Processing alpha Levels:   7%|▋         | 1/15 [00:15<03:31, 15.14s/it]
# Processing alpha Levels:  13%|█▎        | 2/15 [00:30<03:16, 15.14s/it]
# Processing alpha Levels:  20%|██        | 3/15 [00:45<03:01, 15.11s/it]
# Processing alpha Levels:  27%|██▋       | 4/15 [01:00<02:45, 15.07s/it]
# Processing alpha Levels:  33%|███▎      | 5/15 [01:15<02:30, 15.06s/it]
# Processing alpha Levels:  40%|████      | 6/15 [01:30<02:15, 15.06s/it]
# Processing alpha Levels:  47%|████▋     | 7/15 [01:45<02:00, 15.07s/it]
# Processing alpha Levels:  53%|█████▎    | 8/15 [02:00<01:45, 15.07s/it]
# Processing alpha Levels:  60%|██████    | 9/15 [02:15<01:30, 15.06s/it]
# Processing alpha Levels:  67%|██████▋   | 10/15 [02:30<01:15, 15.12s/it]
# Processing alpha Levels:  73%|███████▎  | 11/15 [02:46<01:00, 15.20s/it]
# Processing alpha Levels:  80%|████████  | 12/15 [03:03<00:47, 15.79s/it]
# Processing alpha Levels:  87%|████████▋ | 13/15 [03:19<00:31, 15.80s/it]
# Processing alpha Levels:  93%|█████████▎| 14/15 [03:34<00:15, 15.71s/it]
# Processing alpha Levels: 100%|██████████| 15/15 [03:49<00:00, 15.50s/it]
# Processing Samples:  50%|█████     | 5/10 [19:01<19:01, 228.34s/it]
# Processing alpha Levels:   0%|          | 0/15 [00:00<?, ?it/s]
# Processing alpha Levels:   7%|▋         | 1/15 [00:15<03:31, 15.10s/it]
# Processing alpha Levels:  13%|█▎        | 2/15 [00:30<03:16, 15.10s/it]
# Processing alpha Levels:  20%|██        | 3/15 [00:45<03:00, 15.08s/it]
# Processing alpha Levels:  27%|██▋       | 4/15 [01:00<02:45, 15.08s/it]
# Processing alpha Levels:  33%|███▎      | 5/15 [01:15<02:31, 15.12s/it]
# Processing alpha Levels:  40%|████      | 6/15 [01:30<02:15, 15.07s/it]
# Processing alpha Levels:  47%|████▋     | 7/15 [01:45<02:01, 15.14s/it]
# Processing alpha Levels:  53%|█████▎    | 8/15 [02:00<01:45, 15.12s/it]
# Processing alpha Levels:  60%|██████    | 9/15 [02:15<01:30, 15.08s/it]
# Processing alpha Levels:  67%|██████▋   | 10/15 [02:30<01:15, 15.06s/it]
# Processing alpha Levels:  73%|███████▎  | 11/15 [02:45<01:00, 15.06s/it]
# Processing alpha Levels:  80%|████████  | 12/15 [03:01<00:45, 15.08s/it]
# Processing alpha Levels:  87%|████████▋ | 13/15 [03:16<00:30, 15.12s/it]
# Processing alpha Levels:  93%|█████████▎| 14/15 [03:31<00:15, 15.10s/it]
# Processing alpha Levels: 100%|██████████| 15/15 [03:46<00:00, 15.13s/it]
# Processing Samples:  60%|██████    | 6/10 [22:48<15:10, 227.73s/it]
# Processing alpha Levels:   0%|          | 0/15 [00:00<?, ?it/s]
# Processing alpha Levels:   7%|▋         | 1/15 [00:15<03:31, 15.08s/it]
# Processing alpha Levels:  13%|█▎        | 2/15 [00:30<03:16, 15.15s/it]
# Processing alpha Levels:  20%|██        | 3/15 [00:45<03:01, 15.09s/it]
# Processing alpha Levels:  27%|██▋       | 4/15 [01:00<02:45, 15.09s/it]
# Processing alpha Levels:  33%|███▎      | 5/15 [01:15<02:30, 15.09s/it]
# Processing alpha Levels:  40%|████      | 6/15 [01:30<02:15, 15.04s/it]
# Processing alpha Levels:  47%|████▋     | 7/15 [01:45<02:00, 15.06s/it]
# Processing alpha Levels:  53%|█████▎    | 8/15 [02:00<01:45, 15.07s/it]
# Processing alpha Levels:  60%|██████    | 9/15 [02:15<01:30, 15.04s/it]
# Processing alpha Levels:  67%|██████▋   | 10/15 [02:30<01:15, 15.05s/it]
# Processing alpha Levels:  73%|███████▎  | 11/15 [02:45<01:00, 15.06s/it]
# Processing alpha Levels:  80%|████████  | 12/15 [03:00<00:45, 15.05s/it]
# Processing alpha Levels:  87%|████████▋ | 13/15 [03:18<00:31, 15.74s/it]
# Processing alpha Levels:  93%|█████████▎| 14/15 [03:33<00:15, 15.75s/it]
# Processing alpha Levels: 100%|██████████| 15/15 [03:49<00:00, 15.69s/it]
# Processing Samples:  70%|███████   | 7/10 [26:37<11:24, 228.29s/it]
# Processing alpha Levels:   0%|          | 0/15 [00:00<?, ?it/s]
# Processing alpha Levels:   7%|▋         | 1/15 [00:15<03:32, 15.16s/it]
# Processing alpha Levels:  13%|█▎        | 2/15 [00:30<03:16, 15.08s/it]
# Processing alpha Levels:  20%|██        | 3/15 [00:45<03:01, 15.09s/it]
# Processing alpha Levels:  27%|██▋       | 4/15 [01:00<02:46, 15.12s/it]
# Processing alpha Levels:  33%|███▎      | 5/15 [01:15<02:31, 15.10s/it]
# Processing alpha Levels:  40%|████      | 6/15 [01:30<02:15, 15.07s/it]
# Processing alpha Levels:  47%|████▋     | 7/15 [01:45<02:00, 15.11s/it]
# Processing alpha Levels:  53%|█████▎    | 8/15 [02:00<01:45, 15.11s/it]
# Processing alpha Levels:  60%|██████    | 9/15 [02:15<01:30, 15.11s/it]
# Processing alpha Levels:  67%|██████▋   | 10/15 [02:30<01:15, 15.09s/it]
# Processing alpha Levels:  73%|███████▎  | 11/15 [02:46<01:00, 15.12s/it]
# Processing alpha Levels:  80%|████████  | 12/15 [03:01<00:45, 15.08s/it]
# Processing alpha Levels:  87%|████████▋ | 13/15 [03:16<00:30, 15.17s/it]
# Processing alpha Levels:  93%|█████████▎| 14/15 [03:31<00:15, 15.14s/it]
# Processing alpha Levels: 100%|██████████| 15/15 [03:46<00:00, 15.13s/it]
# Processing Samples:  80%|████████  | 8/10 [30:24<07:35, 227.79s/it]
# Processing alpha Levels:   0%|          | 0/15 [00:00<?, ?it/s]
# Processing alpha Levels:   7%|▋         | 1/15 [00:15<03:32, 15.21s/it]
# Processing alpha Levels:  13%|█▎        | 2/15 [00:30<03:16, 15.14s/it]
# Processing alpha Levels:  20%|██        | 3/15 [00:45<03:01, 15.09s/it]
# Processing alpha Levels:  27%|██▋       | 4/15 [01:00<02:46, 15.11s/it]
# Processing alpha Levels:  33%|███▎      | 5/15 [01:15<02:31, 15.14s/it]
# Processing alpha Levels:  40%|████      | 6/15 [01:30<02:16, 15.13s/it]
# Processing alpha Levels:  47%|████▋     | 7/15 [01:45<02:00, 15.11s/it]
# Processing alpha Levels:  53%|█████▎    | 8/15 [02:00<01:45, 15.12s/it]
# Processing alpha Levels:  60%|██████    | 9/15 [02:16<01:30, 15.12s/it]
# Processing alpha Levels:  67%|██████▋   | 10/15 [02:31<01:15, 15.10s/it]
# Processing alpha Levels:  73%|███████▎  | 11/15 [02:46<01:00, 15.12s/it]
# Processing alpha Levels:  80%|████████  | 12/15 [03:01<00:45, 15.11s/it]
# Processing alpha Levels:  87%|████████▋ | 13/15 [03:16<00:30, 15.18s/it]
# Processing alpha Levels:  93%|█████████▎| 14/15 [03:33<00:15, 15.69s/it]
# Processing alpha Levels: 100%|██████████| 15/15 [03:48<00:00, 15.47s/it]
# Processing Samples:  90%|█████████ | 9/10 [34:13<03:48, 228.04s/it]
# Processing alpha Levels:   0%|          | 0/15 [00:00<?, ?it/s]
# Processing alpha Levels:   7%|▋         | 1/15 [00:15<03:40, 15.73s/it]
# Processing alpha Levels:  13%|█▎        | 2/15 [00:30<03:18, 15.28s/it]
# Processing alpha Levels:  20%|██        | 3/15 [00:45<03:03, 15.28s/it]
# Processing alpha Levels:  27%|██▋       | 4/15 [01:01<02:48, 15.29s/it]
# Processing alpha Levels:  33%|███▎      | 5/15 [01:16<02:33, 15.38s/it]
# Processing alpha Levels:  40%|████      | 6/15 [01:31<02:17, 15.29s/it]
# Processing alpha Levels:  47%|████▋     | 7/15 [01:47<02:01, 15.23s/it]
# Processing alpha Levels:  53%|█████▎    | 8/15 [02:02<01:46, 15.17s/it]
# Processing alpha Levels:  60%|██████    | 9/15 [02:17<01:30, 15.13s/it]
# Processing alpha Levels:  67%|██████▋   | 10/15 [02:32<01:15, 15.15s/it]
# Processing alpha Levels:  73%|███████▎  | 11/15 [02:47<01:00, 15.15s/it]
# Processing alpha Levels:  80%|████████  | 12/15 [03:02<00:45, 15.14s/it]
# Processing alpha Levels:  87%|████████▋ | 13/15 [03:17<00:30, 15.13s/it]
# Processing alpha Levels:  93%|█████████▎| 14/15 [03:32<00:15, 15.13s/it]
# Processing alpha Levels: 100%|██████████| 15/15 [03:48<00:00, 15.18s/it]
# Processing Samples: 100%|██████████| 10/10 [38:01<00:00, 228.12s/it]

# %%
np.savez_compressed(
    f'{base_path}/hyper_parameter_tuning/ca_hg_sbl_danc/data/ca_hg_sbl_danc_alpha_alln_snr_db_12_pilot_length_25.npz',
    gamma_result_all=gamma_result_all,
    z_result_all=z_result_all,
    beta_array = beta_array,
)

print("All results have been saved")
# Out:
# All results have been saved
