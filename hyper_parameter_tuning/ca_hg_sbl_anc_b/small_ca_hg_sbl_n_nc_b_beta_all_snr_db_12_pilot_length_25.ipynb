# %%
base_path = "/content/drive/My Drive/Github/ca-hg-sbl-for-jadce-in-mtc"

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# Load saved data
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append(f'{base_path}/frameworks')

from ca_hg_sbl_n import ca_hg_sbl_n, build_precision_matrix_nc

data = np.load(f'{base_path}/general_model/data/general_model.npz', allow_pickle=True)
all_DeviceLocations = data['all_DeviceLocations']
num_samples = data['num_samples']
device_count = data['device_count']
sparsity = data['sparsity']

data = np.load(f'{base_path}/communication_model/data/communication_simulation_theta.npz', allow_pickle=True)
all_theta = data["all_theta"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_gamma.npz', allow_pickle=True)
all_gamma = data["all_gamma"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_z.npz', allow_pickle=True)
all_z = data["all_z"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_noise.npz', allow_pickle=True)
all_noise = data["all_noise"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_received_signal.npz', allow_pickle=True)
all_received_signal = data["all_received_signal"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_general.npz', allow_pickle=True)
snr_db_array = data["snr_db_array"]
pilot_length_array = data["pilot_length_array"]
M = data["M"]

pilot_length_index = 1
pilot_length=pilot_length_array[pilot_length_index]

snr_db_index = 2
snr_db=snr_db_array[snr_db_index]

beta_array = [1.5, 1.6, 1.7, 1.8, 1.9, 2.0, 2.1, 2.2, 2.3, 2.4, 2.5]
# Out:
# Mounted at /content/drive

# %%
sample_range = range(0, 10)
num_samples = len(sample_range)

# %%
# Final gamma and z results
gamma_result_all = np.empty((num_samples, len(beta_array)), dtype=object)
z_result_all = np.empty((num_samples, len(beta_array)), dtype=object)

# %%
for sample_index in tqdm(sample_range, desc="Processing Samples", position=0):
    gamma = all_gamma[sample_index]  # Ground truth gamma values (true support)
    loc = all_DeviceLocations[sample_index]
    z = all_z[sample_index]

    for beta_index in tqdm(range(len(beta_array)), desc="Processing alpha Levels", leave=False, position=1):
        alpha = 1.0
        beta = beta_array[beta_index]

        theta = all_theta[sample_index, pilot_length_index, :pilot_length]
        received_signal = all_received_signal[sample_index, pilot_length_index, snr_db_index, :pilot_length]

        # Compute noise
        snr = 10 ** (snr_db / 10)
        signal_power = np.mean(np.abs(np.matmul(theta, z))**2)
        noise_power = signal_power / snr

        # Compute precision matrix
        precision_matrix = build_precision_matrix_nc(loc, alpha=alpha)

        # Run CASBL
        gamma_result, z_result, gamma_history, z_history, iteration_count = ca_hg_sbl_n(
            theta, received_signal, noise_power, precision_matrix, bias = beta, bounded = True
        )

        # Save outputs
        gamma_result_all[sample_index-sample_range[0], beta_index] = gamma_result.copy()
        z_result_all[sample_index-sample_range[0], beta_index] = z_result.copy()
# Out:
# Processing Samples:   0%|          | 0/10 [00:00<?, ?it/s]
# Processing alpha Levels:   0%|          | 0/11 [00:00<?, ?it/s]
# Processing alpha Levels:   9%|▉         | 1/11 [00:20<03:28, 20.81s/it]
# Processing alpha Levels:  18%|█▊        | 2/11 [00:37<02:46, 18.47s/it]
# Processing alpha Levels:  27%|██▋       | 3/11 [00:53<02:17, 17.18s/it]
# Processing alpha Levels:  36%|███▋      | 4/11 [01:08<01:55, 16.53s/it]
# Processing alpha Levels:  45%|████▌     | 5/11 [01:24<01:37, 16.18s/it]
# Processing alpha Levels:  55%|█████▍    | 6/11 [01:40<01:21, 16.20s/it]
# Processing alpha Levels:  64%|██████▎   | 7/11 [01:57<01:05, 16.39s/it]
# Processing alpha Levels:  73%|███████▎  | 8/11 [02:14<00:49, 16.54s/it]
# Processing alpha Levels:  82%|████████▏ | 9/11 [02:34<00:35, 17.60s/it]
# Processing alpha Levels:  91%|█████████ | 10/11 [02:51<00:17, 17.44s/it]
# Processing alpha Levels: 100%|██████████| 11/11 [03:08<00:00, 17.23s/it]
# Processing Samples:  10%|█         | 1/10 [03:08<28:12, 188.04s/it]
# Processing alpha Levels:   0%|          | 0/11 [00:00<?, ?it/s]
# Processing alpha Levels:   9%|▉         | 1/11 [00:16<02:46, 16.63s/it]
# Processing alpha Levels:  18%|█▊        | 2/11 [00:33<02:29, 16.64s/it]
# Processing alpha Levels:  27%|██▋       | 3/11 [00:49<02:13, 16.67s/it]
# Processing alpha Levels:  36%|███▋      | 4/11 [01:08<02:02, 17.47s/it]
# Processing alpha Levels:  45%|████▌     | 5/11 [01:27<01:46, 17.81s/it]
# Processing alpha Levels:  55%|█████▍    | 6/11 [01:43<01:27, 17.43s/it]
# Processing alpha Levels:  64%|██████▎   | 7/11 [02:00<01:08, 17.18s/it]
# Processing alpha Levels:  73%|███████▎  | 8/11 [02:17<00:51, 17.00s/it]
# Processing alpha Levels:  82%|████████▏ | 9/11 [02:33<00:33, 16.89s/it]
# Processing alpha Levels:  91%|█████████ | 10/11 [02:50<00:16, 16.86s/it]
# Processing alpha Levels: 100%|██████████| 11/11 [03:10<00:00, 17.95s/it]
# Processing Samples:  20%|██        | 2/10 [06:19<25:18, 189.76s/it]
# Processing alpha Levels:   0%|          | 0/11 [00:00<?, ?it/s]
# Processing alpha Levels:   9%|▉         | 1/11 [00:17<02:50, 17.03s/it]
# Processing alpha Levels:  18%|█▊        | 2/11 [00:33<02:32, 16.97s/it]
# Processing alpha Levels:  27%|██▋       | 3/11 [00:50<02:15, 16.96s/it]
# Processing alpha Levels:  36%|███▋      | 4/11 [01:07<01:58, 16.93s/it]
# Processing alpha Levels:  45%|████▌     | 5/11 [01:25<01:42, 17.13s/it]
# Processing alpha Levels:  55%|█████▍    | 6/11 [01:45<01:30, 18.20s/it]
# Processing alpha Levels:  64%|██████▎   | 7/11 [02:02<01:11, 17.78s/it]
# Processing alpha Levels:  73%|███████▎  | 8/11 [02:19<00:52, 17.53s/it]
# Processing alpha Levels:  82%|████████▏ | 9/11 [02:36<00:34, 17.29s/it]
# Processing alpha Levels:  91%|█████████ | 10/11 [02:53<00:17, 17.17s/it]
# Processing alpha Levels: 100%|██████████| 11/11 [03:11<00:00, 17.54s/it]
# Processing Samples:  30%|███       | 3/10 [09:30<22:13, 190.56s/it]
# Processing alpha Levels:   0%|          | 0/11 [00:00<?, ?it/s]
# Processing alpha Levels:   9%|▉         | 1/11 [00:18<03:04, 18.45s/it]
# Processing alpha Levels:  18%|█▊        | 2/11 [00:35<02:36, 17.43s/it]
# Processing alpha Levels:  27%|██▋       | 3/11 [00:51<02:16, 17.08s/it]
# Processing alpha Levels:  36%|███▋      | 4/11 [01:08<01:58, 16.97s/it]
# Processing alpha Levels:  45%|████▌     | 5/11 [01:25<01:41, 16.87s/it]
# Processing alpha Levels:  55%|█████▍    | 6/11 [01:42<01:24, 16.87s/it]
# Processing alpha Levels:  64%|██████▎   | 7/11 [02:02<01:11, 17.95s/it]
# Processing alpha Levels:  73%|███████▎  | 8/11 [02:19<00:52, 17.57s/it]
# Processing alpha Levels:  82%|████████▏ | 9/11 [02:35<00:34, 17.32s/it]
# Processing alpha Levels:  91%|█████████ | 10/11 [02:52<00:17, 17.12s/it]
# Processing alpha Levels: 100%|██████████| 11/11 [03:09<00:00, 17.00s/it]
# Processing Samples:  40%|████      | 4/10 [12:39<19:00, 190.07s/it]
# Processing alpha Levels:   0%|          | 0/11 [00:00<?, ?it/s]
# Processing alpha Levels:   9%|▉         | 1/11 [00:16<02:48, 16.81s/it]
# Processing alpha Levels:  18%|█▊        | 2/11 [00:36<02:45, 18.34s/it]
# Processing alpha Levels:  27%|██▋       | 3/11 [00:53<02:23, 18.00s/it]
# Processing alpha Levels:  36%|███▋      | 4/11 [01:10<02:02, 17.52s/it]
# Processing alpha Levels:  45%|████▌     | 5/11 [01:27<01:43, 17.26s/it]
# Processing alpha Levels:  55%|█████▍    | 6/11 [01:44<01:25, 17.09s/it]
# Processing alpha Levels:  64%|██████▎   | 7/11 [02:00<01:07, 16.97s/it]
# Processing alpha Levels:  73%|███████▎  | 8/11 [02:19<00:52, 17.42s/it]
# Processing alpha Levels:  82%|████████▏ | 9/11 [02:37<00:35, 17.72s/it]
# Processing alpha Levels:  91%|█████████ | 10/11 [02:54<00:17, 17.40s/it]
# Processing alpha Levels: 100%|██████████| 11/11 [03:11<00:00, 17.21s/it]
# Processing Samples:  50%|█████     | 5/10 [15:50<15:52, 190.46s/it]
# Processing alpha Levels:   0%|          | 0/11 [00:00<?, ?it/s]
# Processing alpha Levels:   9%|▉         | 1/11 [00:16<02:48, 16.86s/it]
# Processing alpha Levels:  18%|█▊        | 2/11 [00:33<02:30, 16.74s/it]
# Processing alpha Levels:  27%|██▋       | 3/11 [00:50<02:14, 16.78s/it]
# Processing alpha Levels:  36%|███▋      | 4/11 [01:10<02:06, 18.14s/it]
# Processing alpha Levels:  45%|████▌     | 5/11 [01:27<01:45, 17.61s/it]
# Processing alpha Levels:  55%|█████▍    | 6/11 [01:43<01:26, 17.30s/it]
# Processing alpha Levels:  64%|██████▎   | 7/11 [02:00<01:08, 17.13s/it]
# Processing alpha Levels:  73%|███████▎  | 8/11 [02:17<00:51, 17.00s/it]
# Processing alpha Levels:  82%|████████▏ | 9/11 [02:34<00:33, 16.91s/it]
# Processing alpha Levels:  91%|█████████ | 10/11 [02:53<00:17, 17.75s/it]
# Processing alpha Levels: 100%|██████████| 11/11 [03:10<00:00, 17.54s/it]
# Processing Samples:  60%|██████    | 6/10 [19:01<12:42, 190.60s/it]
# Processing alpha Levels:   0%|          | 0/11 [00:00<?, ?it/s]
# Processing alpha Levels:   9%|▉         | 1/11 [00:16<02:47, 16.71s/it]
# Processing alpha Levels:  18%|█▊        | 2/11 [00:33<02:30, 16.68s/it]
# Processing alpha Levels:  27%|██▋       | 3/11 [00:49<02:13, 16.65s/it]
# Processing alpha Levels:  36%|███▋      | 4/11 [01:06<01:56, 16.62s/it]
# Processing alpha Levels:  45%|████▌     | 5/11 [01:23<01:41, 16.86s/it]
# Processing alpha Levels:  55%|█████▍    | 6/11 [01:43<01:28, 17.78s/it]
# Processing alpha Levels:  64%|██████▎   | 7/11 [01:59<01:09, 17.39s/it]
# Processing alpha Levels:  73%|███████▎  | 8/11 [02:16<00:51, 17.15s/it]
# Processing alpha Levels:  82%|████████▏ | 9/11 [02:33<00:33, 16.99s/it]
# Processing alpha Levels:  91%|█████████ | 10/11 [02:49<00:16, 16.87s/it]
# Processing alpha Levels: 100%|██████████| 11/11 [03:06<00:00, 16.80s/it]
# Processing Samples:  70%|███████   | 7/10 [22:08<09:27, 189.27s/it]
# Processing alpha Levels:   0%|          | 0/11 [00:00<?, ?it/s]
# Processing alpha Levels:   9%|▉         | 1/11 [00:18<03:05, 18.60s/it]
# Processing alpha Levels:  18%|█▊        | 2/11 [00:36<02:42, 18.10s/it]
# Processing alpha Levels:  27%|██▋       | 3/11 [00:52<02:19, 17.43s/it]
# Processing alpha Levels:  36%|███▋      | 4/11 [01:09<01:59, 17.08s/it]
# Processing alpha Levels:  45%|████▌     | 5/11 [01:26<01:41, 16.88s/it]
# Processing alpha Levels:  55%|█████▍    | 6/11 [01:42<01:23, 16.79s/it]
# Processing alpha Levels:  64%|██████▎   | 7/11 [01:59<01:06, 16.69s/it]
# Processing alpha Levels:  73%|███████▎  | 8/11 [02:18<00:52, 17.62s/it]
# Processing alpha Levels:  82%|████████▏ | 9/11 [02:35<00:34, 17.46s/it]
# Processing alpha Levels:  91%|█████████ | 10/11 [02:52<00:17, 17.20s/it]
# Processing alpha Levels: 100%|██████████| 11/11 [03:09<00:00, 17.00s/it]
# Processing Samples:  80%|████████  | 8/10 [25:17<06:18, 189.19s/it]
# Processing alpha Levels:   0%|          | 0/11 [00:00<?, ?it/s]
# Processing alpha Levels:   9%|▉         | 1/11 [00:16<02:45, 16.59s/it]
# Processing alpha Levels:  18%|█▊        | 2/11 [00:33<02:29, 16.58s/it]
# Processing alpha Levels:  27%|██▋       | 3/11 [00:49<02:12, 16.54s/it]
# Processing alpha Levels:  36%|███▋      | 4/11 [01:09<02:05, 17.93s/it]
# Processing alpha Levels:  45%|████▌     | 5/11 [01:26<01:44, 17.45s/it]
# Processing alpha Levels:  55%|█████▍    | 6/11 [01:42<01:25, 17.17s/it]
# Processing alpha Levels:  64%|██████▎   | 7/11 [01:59<01:07, 16.97s/it]
# Processing alpha Levels:  73%|███████▎  | 8/11 [02:15<00:50, 16.71s/it]
# Processing alpha Levels:  82%|████████▏ | 9/11 [02:32<00:33, 16.68s/it]
# Processing alpha Levels:  91%|█████████ | 10/11 [02:48<00:16, 16.68s/it]
# Processing alpha Levels: 100%|██████████| 11/11 [03:08<00:00, 17.68s/it]
# Processing Samples:  90%|█████████ | 9/10 [28:26<03:09, 189.10s/it]
# Processing alpha Levels:   0%|          | 0/11 [00:00<?, ?it/s]
# Processing alpha Levels:   9%|▉         | 1/11 [00:16<02:40, 16.05s/it]
# Processing alpha Levels:  18%|█▊        | 2/11 [00:32<02:27, 16.39s/it]
# Processing alpha Levels:  27%|██▋       | 3/11 [00:49<02:11, 16.45s/it]
# Processing alpha Levels:  36%|███▋      | 4/11 [01:05<01:55, 16.46s/it]
# Processing alpha Levels:  45%|████▌     | 5/11 [01:21<01:37, 16.30s/it]
# Processing alpha Levels:  55%|█████▍    | 6/11 [01:38<01:22, 16.55s/it]
# Processing alpha Levels:  64%|██████▎   | 7/11 [01:58<01:09, 17.48s/it]
# Processing alpha Levels:  73%|███████▎  | 8/11 [02:13<00:50, 16.91s/it]
# Converged after 467 iterations
# Processing alpha Levels:  82%|████████▏ | 9/11 [02:28<00:32, 16.32s/it]
# Converged after 461 iterations
# Processing alpha Levels:  91%|█████████ | 10/11 [02:45<00:16, 16.38s/it]
# Processing alpha Levels: 100%|██████████| 11/11 [03:01<00:00, 16.43s/it]
# Processing Samples: 100%|██████████| 10/10 [31:28<00:00, 188.82s/it]

# %%
np.savez_compressed(
    f'{base_path}/hyper_parameter_tuning/ca_hg_sbl_anc_b/data/small_ca_hg_sbl_n_nc_b_beta_all_snr_db_12_pilot_length_25.npz',
    gamma_result_all=gamma_result_all,
    z_result_all=z_result_all,
    beta_array = beta_array,
)

print("All results have been saved")
# Out:
# All results have been saved
