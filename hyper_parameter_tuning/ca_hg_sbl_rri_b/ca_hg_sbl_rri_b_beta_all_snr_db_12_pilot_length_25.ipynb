# %%
base_path = "/content/drive/My Drive/Github/ca-hg-sbl-for-jadce-in-mtc"

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# Load saved data
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append(f'{base_path}/frameworks')

from ca_hg_sbl import ca_hg_sbl, build_precision_matrix_rri

data = np.load(f'{base_path}/general_model/data/general_model.npz', allow_pickle=True)
all_DeviceLocations = data['all_DeviceLocations']
num_samples = data['num_samples']
device_count = data['device_count']
sparsity = data['sparsity']

data = np.load(f'{base_path}/communication_model/data/communication_simulation_theta.npz', allow_pickle=True)
all_theta = data["all_theta"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_gamma.npz', allow_pickle=True)
all_gamma = data["all_gamma"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_z.npz', allow_pickle=True)
all_z = data["all_z"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_noise.npz', allow_pickle=True)
all_noise = data["all_noise"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_received_signal.npz', allow_pickle=True)
all_received_signal = data["all_received_signal"]

data = np.load(f'{base_path}/communication_model/data/communication_simulation_general.npz', allow_pickle=True)
snr_db_array = data["snr_db_array"]
pilot_length_array = data["pilot_length_array"]
M = data["M"]

pilot_length_index = 1
pilot_length=pilot_length_array[pilot_length_index]

snr_db_index = 2
snr_db=snr_db_array[snr_db_index]

beta_array = [10, 20, 30, 40, 50, 60, 70, 80]
# Out:
# Mounted at /content/drive

# %%
sample_range = range(0, 10)
num_samples = len(sample_range)

# %%
# Final gamma and z results
gamma_result_all = np.empty((num_samples, len(beta_array)), dtype=object)
z_result_all = np.empty((num_samples, len(beta_array)), dtype=object)

# %%
for sample_index in tqdm(sample_range, desc="Processing Samples", position=0):
    gamma = all_gamma[sample_index]  # Ground truth gamma values (true support)
    loc = all_DeviceLocations[sample_index]
    z = all_z[sample_index]

    for beta_index in tqdm(range(len(beta_array)), desc="Processing alpha Levels", leave=False, position=1):
        alpha = 1.0
        beta = beta_array[beta_index]

        theta = all_theta[sample_index, pilot_length_index, :pilot_length]
        received_signal = all_received_signal[sample_index, pilot_length_index, snr_db_index, :pilot_length]

        # Compute noise
        snr = 10 ** (snr_db / 10)
        signal_power = np.mean(np.abs(np.matmul(theta, z))**2)
        noise_power = signal_power / snr

        # Compute precision matrix
        precision_matrix = build_precision_matrix_rri(loc, alpha=alpha, beta=beta)

        # Run CASBL
        gamma_result, z_result, gamma_history, z_history, iteration_count = ca_hg_sbl(
            theta, received_signal, noise_power, precision_matrix, bounded = True
        )

        # Save outputs
        gamma_result_all[sample_index-sample_range[0], beta_index] = gamma_result.copy()
        z_result_all[sample_index-sample_range[0], beta_index] = z_result.copy()
# Out:
# Processing Samples:   0%|          | 0/10 [00:00<?, ?it/s]
# Processing alpha Levels:   0%|          | 0/8 [00:00<?, ?it/s]
# Processing alpha Levels:  12%|█▎        | 1/8 [00:19<02:14, 19.28s/it]
# Processing alpha Levels:  25%|██▌       | 2/8 [00:37<01:50, 18.49s/it]
# Processing alpha Levels:  38%|███▊      | 3/8 [00:54<01:30, 18.08s/it]
# Processing alpha Levels:  50%|█████     | 4/8 [01:12<01:11, 17.99s/it]
# Processing alpha Levels:  62%|██████▎   | 5/8 [01:34<00:57, 19.20s/it]
# Processing alpha Levels:  75%|███████▌  | 6/8 [01:52<00:37, 18.94s/it]
# Processing alpha Levels:  88%|████████▊ | 7/8 [02:10<00:18, 18.81s/it]
# Processing alpha Levels: 100%|██████████| 8/8 [02:29<00:00, 18.73s/it]
# Processing Samples:  10%|█         | 1/10 [02:29<22:25, 149.55s/it]
# Processing alpha Levels:   0%|          | 0/8 [00:00<?, ?it/s]
# Processing alpha Levels:  12%|█▎        | 1/8 [00:22<02:35, 22.18s/it]
# Processing alpha Levels:  25%|██▌       | 2/8 [00:39<01:57, 19.58s/it]
# Processing alpha Levels:  38%|███▊      | 3/8 [01:00<01:41, 20.25s/it]
# Processing alpha Levels:  50%|█████     | 4/8 [01:18<01:17, 19.28s/it]
# Processing alpha Levels:  62%|██████▎   | 5/8 [01:40<01:00, 20.04s/it]
# Processing alpha Levels:  75%|███████▌  | 6/8 [01:57<00:38, 19.24s/it]
# Processing alpha Levels:  88%|████████▊ | 7/8 [02:15<00:18, 18.75s/it]
# Processing alpha Levels: 100%|██████████| 8/8 [02:33<00:00, 18.43s/it]
# Processing Samples:  20%|██        | 2/10 [05:02<20:14, 151.79s/it]
# Processing alpha Levels:   0%|          | 0/8 [00:00<?, ?it/s]
# Processing alpha Levels:  12%|█▎        | 1/8 [00:17<02:04, 17.75s/it]
# Processing alpha Levels:  25%|██▌       | 2/8 [00:39<01:59, 19.90s/it]
# Processing alpha Levels:  38%|███▊      | 3/8 [00:56<01:34, 18.83s/it]
# Processing alpha Levels:  50%|█████     | 4/8 [01:14<01:13, 18.37s/it]
# Processing alpha Levels:  62%|██████▎   | 5/8 [01:31<00:54, 18.09s/it]
# Processing alpha Levels:  75%|███████▌  | 6/8 [01:57<00:40, 20.47s/it]
# Processing alpha Levels:  88%|████████▊ | 7/8 [02:14<00:19, 19.58s/it]
# Processing alpha Levels: 100%|██████████| 8/8 [02:32<00:00, 18.99s/it]
# Processing Samples:  30%|███       | 3/10 [07:35<17:45, 152.14s/it]
# Processing alpha Levels:   0%|          | 0/8 [00:00<?, ?it/s]
# Processing alpha Levels:  12%|█▎        | 1/8 [00:21<02:30, 21.53s/it]
# Processing alpha Levels:  25%|██▌       | 2/8 [00:39<01:55, 19.23s/it]
# Processing alpha Levels:  38%|███▊      | 3/8 [00:56<01:32, 18.58s/it]
# Processing alpha Levels:  50%|█████     | 4/8 [01:14<01:13, 18.28s/it]
# Processing alpha Levels:  62%|██████▎   | 5/8 [01:32<00:54, 18.15s/it]
# Processing alpha Levels:  75%|███████▌  | 6/8 [01:54<00:38, 19.25s/it]
# Processing alpha Levels:  88%|████████▊ | 7/8 [02:11<00:18, 18.77s/it]
# Processing alpha Levels: 100%|██████████| 8/8 [02:29<00:00, 18.39s/it]
# Processing Samples:  40%|████      | 4/10 [10:04<15:06, 151.09s/it]
# Processing alpha Levels:   0%|          | 0/8 [00:00<?, ?it/s]
# Processing alpha Levels:  12%|█▎        | 1/8 [00:19<02:17, 19.68s/it]
# Processing alpha Levels:  25%|██▌       | 2/8 [00:37<01:51, 18.55s/it]
# Processing alpha Levels:  38%|███▊      | 3/8 [00:58<01:38, 19.79s/it]
# Processing alpha Levels:  50%|█████     | 4/8 [01:16<01:15, 18.98s/it]
# Processing alpha Levels:  62%|██████▎   | 5/8 [01:34<00:55, 18.49s/it]
# Processing alpha Levels:  75%|███████▌  | 6/8 [01:51<00:36, 18.26s/it]
# Processing alpha Levels:  88%|████████▊ | 7/8 [02:11<00:18, 18.81s/it]
# Processing alpha Levels: 100%|██████████| 8/8 [02:31<00:00, 18.96s/it]
# Processing Samples:  50%|█████     | 5/10 [12:36<12:35, 151.10s/it]
# Processing alpha Levels:   0%|          | 0/8 [00:00<?, ?it/s]
# Processing alpha Levels:  12%|█▎        | 1/8 [00:17<02:04, 17.85s/it]
# Processing alpha Levels:  25%|██▌       | 2/8 [00:35<01:47, 17.86s/it]
# Processing alpha Levels:  38%|███▊      | 3/8 [00:53<01:28, 17.77s/it]
# Processing alpha Levels:  50%|█████     | 4/8 [01:14<01:16, 19.16s/it]
# Processing alpha Levels:  62%|██████▎   | 5/8 [01:32<00:55, 18.62s/it]
# Processing alpha Levels:  75%|███████▌  | 6/8 [01:49<00:36, 18.28s/it]
# Processing alpha Levels:  88%|████████▊ | 7/8 [02:07<00:18, 18.09s/it]
# Processing alpha Levels: 100%|██████████| 8/8 [02:25<00:00, 17.95s/it]
# Processing Samples:  60%|██████    | 6/10 [15:01<09:56, 149.14s/it]
# Processing alpha Levels:   0%|          | 0/8 [00:00<?, ?it/s]
# Processing alpha Levels:  12%|█▎        | 1/8 [00:21<02:27, 21.11s/it]
# Processing alpha Levels:  25%|██▌       | 2/8 [00:38<01:53, 18.88s/it]
# Processing alpha Levels:  38%|███▊      | 3/8 [00:55<01:31, 18.20s/it]
# Processing alpha Levels:  50%|█████     | 4/8 [01:13<01:11, 17.92s/it]
# Processing alpha Levels:  62%|██████▎   | 5/8 [01:30<00:53, 17.78s/it]
# Processing alpha Levels:  75%|███████▌  | 6/8 [01:51<00:37, 18.89s/it]
# Processing alpha Levels:  88%|████████▊ | 7/8 [02:12<00:19, 19.55s/it]
# Processing alpha Levels: 100%|██████████| 8/8 [02:30<00:00, 18.95s/it]
# Processing Samples:  70%|███████   | 7/10 [17:31<07:28, 149.58s/it]
# Processing alpha Levels:   0%|          | 0/8 [00:00<?, ?it/s]
# Processing alpha Levels:  12%|█▎        | 1/8 [00:17<02:01, 17.39s/it]
# Processing alpha Levels:  25%|██▌       | 2/8 [00:34<01:44, 17.40s/it]
# Processing alpha Levels:  38%|███▊      | 3/8 [00:56<01:35, 19.14s/it]
# Processing alpha Levels:  50%|█████     | 4/8 [01:13<01:14, 18.52s/it]
# Processing alpha Levels:  62%|██████▎   | 5/8 [01:31<00:54, 18.14s/it]
# Processing alpha Levels:  75%|███████▌  | 6/8 [01:48<00:35, 17.91s/it]
# Processing alpha Levels:  88%|████████▊ | 7/8 [02:06<00:17, 17.91s/it]
# Processing alpha Levels: 100%|██████████| 8/8 [02:27<00:00, 18.97s/it]
# Processing Samples:  80%|████████  | 8/10 [19:59<04:57, 148.97s/it]
# Processing alpha Levels:   0%|          | 0/8 [00:00<?, ?it/s]
# Processing alpha Levels:  12%|█▎        | 1/8 [00:17<02:02, 17.54s/it]
# Processing alpha Levels:  25%|██▌       | 2/8 [00:38<01:57, 19.60s/it]
# Processing alpha Levels:  38%|███▊      | 3/8 [01:00<01:42, 20.53s/it]
# Processing alpha Levels:  50%|█████     | 4/8 [01:17<01:17, 19.32s/it]
# Processing alpha Levels:  62%|██████▎   | 5/8 [01:35<00:56, 18.71s/it]
# Processing alpha Levels:  75%|███████▌  | 6/8 [01:52<00:36, 18.27s/it]
# Processing alpha Levels:  88%|████████▊ | 7/8 [02:11<00:18, 18.30s/it]
# Processing alpha Levels: 100%|██████████| 8/8 [02:31<00:00, 18.91s/it]
# Processing Samples:  90%|█████████ | 9/10 [22:30<02:29, 149.71s/it]
# Processing alpha Levels:   0%|          | 0/8 [00:00<?, ?it/s]
# Processing alpha Levels:  12%|█▎        | 1/8 [00:17<02:03, 17.68s/it]
# Processing alpha Levels:  25%|██▌       | 2/8 [00:35<01:45, 17.64s/it]
# Processing alpha Levels:  38%|███▊      | 3/8 [00:52<01:27, 17.57s/it]
# Processing alpha Levels:  50%|█████     | 4/8 [01:10<01:10, 17.62s/it]
# Processing alpha Levels:  62%|██████▎   | 5/8 [01:33<00:58, 19.55s/it]
# Processing alpha Levels:  75%|███████▌  | 6/8 [01:52<00:38, 19.35s/it]
# Processing alpha Levels:  88%|████████▊ | 7/8 [02:09<00:18, 18.75s/it]
# Processing alpha Levels: 100%|██████████| 8/8 [02:27<00:00, 18.32s/it]
# Processing Samples: 100%|██████████| 10/10 [24:58<00:00, 149.82s/it]

# %%
np.savez_compressed(
    f'{base_path}/hyper_parameter_tuning/ca_hg_sbl_rri_b/data/ca_hg_sbl_rri_b_beta_all_snr_db_12_pilot_length_25.npz',
    gamma_result_all=gamma_result_all,
    z_result_all=z_result_all,
    beta_array = beta_array,
)

print("All results have been saved")
# Out:
# All results have been saved
